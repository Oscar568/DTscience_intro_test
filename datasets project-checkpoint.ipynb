# %%
import pandas as pd

# Reading the CSV files and storing them in variables
df_companies = pd.read_csv('S&P 500 Stocks/sp500_companies.csv')
#df_index = pd.read_csv('S&P 500 Stocks/sp500_index.csv')
# df_stocks = pd.read_csv('S&P 500 Stocks/sp500_stocks.csv')

# Now you can work with the DataFrames (df_companies, df_index, df_stocks)
# print(df_index)
# Out:
#     Exchange Symbol                      Shortname  \
# 0        NMS   AAPL                     Apple Inc.
# 1        NMS   NVDA             NVIDIA Corporation
# 2        NMS   MSFT          Microsoft Corporation
# 3        NMS  GOOGL                  Alphabet Inc.
# 4        NMS   GOOG                  Alphabet Inc.
# ..       ...    ...                            ...
# 498      NYQ    BWA                BorgWarner Inc.
# 499      NYQ    IVZ                    Invesco Ltd
# 500      NMS   PARA               Paramount Global
# 501      NMS    AAL  American Airlines Group, Inc.
# 502      NMS   ETSY                     Etsy, Inc.
#
#                          Longname                  Sector  \
# 0                      Apple Inc.              Technology
# 1              NVIDIA Corporation              Technology
# 2           Microsoft Corporation              Technology
# 3                   Alphabet Inc.  Communication Services
# ...

# %%
# import glob
# import pandas as pd

# # Specify the path to the folder containing the CSV files
# path = "C:/Users/oalex/Desktop/udemy/Udemy Modules/jupyter notebook section 307/S&P 500 Stocks"

# # Use glob to find all CSV files in the specified folder
# all_files = glob.glob(path + "/*.csv")

# # Read and concatenate all CSV files into one DataFrame
# df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# # Display the DataFrame
# print(df)

# %%
import pandas as pd
data_companies = pd.read_csv('S&P 500 Stocks/sp500_companies.csv')
data_companies

# %%
data_companies.describe()
# Out:
#        Currentprice     Marketcap        Ebitda  Revenuegrowth  \
# count    503.000000  5.030000e+02  4.740000e+02     501.000000
# mean     219.721203  1.038409e+11  6.768563e+09       0.059593
# std      494.223935  3.083521e+11  1.477401e+10       0.174757
# min        8.110000  6.356113e+09 -4.107000e+09      -0.573000
# 25%       67.815000  1.926171e+10  1.595674e+09      -0.002000
# 50%      122.530000  3.638441e+10  2.880500e+09       0.047000
# 75%      234.430000  7.467920e+10  5.874562e+09       0.096000
# max     9076.030000  3.466991e+12  1.317810e+11       2.621000
#
#        Fulltimeemployees      Weight
# count       4.950000e+02  503.000000
# mean        5.814839e+04    0.001988
# std         1.394515e+05    0.005904
# min         2.800000e+01    0.000122
# 25%         1.007550e+04    0.000369
# 50%         2.124900e+04    0.000697
# 75%         5.354100e+04    0.001430
# max         2.100000e+06    0.066377

# %%
#Cleaning data with specific methods
df1 = pd.DataFrame(data_companies, columns = ['Currentprice','Marketcap','Revenuegrowth'])
#to display all data
pd.set_option('display.max_rows', None)

df1['difference'] = df1['Currentprice']- df1['Revenuegrowth']
df1.sort_values('difference', ascending = False)
# Out:
#      Currentprice      Marketcap  Revenuegrowth  difference
# 300      9076.030    27932299264          0.117    9075.913
# 75       3881.450   130123284480          0.073    3881.377
# 172      3181.850    54354907136          0.035    3181.815
# 219      1714.900    42046775296          0.123    1714.777
# 280      1422.590    30186221568         -0.036    1422.626
# 126      1326.230    74416619520          0.173    1326.057
# 72       1201.760   132476018688          0.123    1201.637
# 145      1127.730    65414766592          0.050    1127.680
# 198       967.360    47232028672          0.031     967.329
# 8         954.480   859438579712          0.360     954.120
# 330       952.840    24212236288          0.221     952.619
# 203       945.460    46093066240          0.150     945.310
# 17        908.900   402947211264          0.091     908.809
# 73        886.130   131260661760          0.077     886.053
# 52        831.740   171219484672          0.222     831.518
# ...

# %%
#seaborn is data visualization library on matplotlib
import seaborn as sns
sns.set()

graph = sns.scatterplot(x= 'Currentprice', y = 'Revenuegrowth', data=df1)
graph
# Out:
# <Axes: xlabel='Currentprice', ylabel='Revenuegrowth'>

# %%
# Bokeh is another library for labaling the information inside a graph
from bokeh.plotting import figure, show
from bokeh.models import HoverTool

hover = HoverTool(tooltips=[])

p = figure(title = "Stock Trends", 
           x_axis_label = 'Currentprice', 
           y_axis_label = 'Revenuegrowth', 
           width=700, height=700, tools = [])
p.line(data('Currentprice', 'Revenuegrowth'), line_width = 2)
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 9
#       3 from bokeh.models import HoverTool
#       5 p = figure(title = "Stock Trends",
#       6            x_axis_label = 'Currentprice',
#       7            y_axis_label = 'Revenuegrowth',
#       8            width=700, height=700, tools = [])
# ----> 9 p.line(data('Currentprice', 'Revenuegrowth'), line_width = 2)
#      10 show(p)
#
# NameError: name 'data' is not defined
